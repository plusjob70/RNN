# %% [markdown]
# # Drive -> Dashboard

# %%
! cp /content/drive/MyDrive/RNN/*.py .

# %%
! cp /content/drive/MyDrive/RNN/stopwords_re.txt .

# %%
! mkdir hypo && cp /content/drive/MyDrive/pt/hypo1/*.pt ./hypo

# %%
! mkdir Data && cp /content/drive/MyDrive/RNN/Data/*.csv ./Data

# %% [markdown]
# # Train

# %%
! python train.py
# Out:
# save vocabulary
# save vocabulary
# load vocabulary
# load vocabulary
# device :  cuda
# create new embedding matrix
# [Epoch 1 / 15]
#   0% 0/1350 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "train.py", line 192, in <module>
#     train(args, train_loader, valid_loader, model)
#   File "train.py", line 120, in train
#     loss = criterion(output, label)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1110, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py", line 1165, in forward
#     label_smoothing=self.label_smoothing)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py", line 2996, in cross_entropy
#     return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
# RuntimeError: "nll_loss_forward_reduce_cuda_kernel_2d_index" not implemented for 'Float'

# %% [markdown]
# # Test

# %%
! python test.py
# Out:
# load vocabulary
# load vocabulary
# create new embedding matrix
# load embedding matrix
# {0: 'education', 1: 'ict', 2: 'mechanics', 3: 'economy'}
# 100% 1/1 [00:00<00:00, 56.25it/s]
# epoch : (model:1, embed:1)
# Test Accuracy : 0.73000
#
#
#
# create new embedding matrix
# load embedding matrix
# {0: 'education', 1: 'ict', 2: 'mechanics', 3: 'economy'}
# 100% 1/1 [00:00<00:00, 66.87it/s]
# epoch : (model:1, embed:2)
# Test Accuracy : 0.75000
#
#
#
# create new embedding matrix
# load embedding matrix
# {0: 'education', 1: 'ict', 2: 'mechanics', 3: 'economy'}
# 100% 1/1 [00:00<00:00, 66.28it/s]
# epoch : (model:1, embed:3)
# Test Accuracy : 0.77000
#
#
#
# create new embedding matrix
# load embedding matrix
# {0: 'education', 1: 'ict', 2: 'mechanics', 3: 'economy'}
# 100% 1/1 [00:00<00:00, 63.94it/s]
# epoch : (model:1, embed:4)
# Test Accuracy : 0.78000
#
#
#
# create new embedding matrix
# load embedding matrix
# {0: 'education', 1: 'ict', 2: 'mechanics', 3: 'economy'}
# ...

# %%
import re

# %%
word = "students`;"
word = re.sub(r"[\']s|’s|[(|)|,|\"|\'|‘|’|`|“|”|:|;|\[|\]|?|!]|(\.(?=[\s\n\r”\"]|$))", '', word).lower().strip()
word
# Out:
# 'students'

# %%
|'“'
# Out:
# '“'

# %%
word2 = '20.22'

def isfloat(s):
    try:
        float(s)
        return True
    except ValueError:
        return False
    
if isfloat(word2):
    word2 = '<FLO>'
word2
# Out:
# '<FLO>'
